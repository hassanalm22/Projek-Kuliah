# %%
import numpy as np
import scipy.signal as signal
import librosa
import matplotlib.pyplot as plt
import soundfile as sf
import os

# Path file audio input
file_path = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window\Indo.wav'

# Path folder untuk menyimpan hasil
output_folder = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window'

# Cek apakah folder output ada
if not os.path.exists(output_folder):
    print(f"Folder tidak ditemukan: {output_folder}")
else:
    # Cek apakah file audio ada
    if not os.path.exists(file_path):
        print(f"File tidak ditemukan: {file_path}")
    else:
        # Muat file audio
        y, sr = librosa.load(file_path, sr=None)

        # Desain low-pass FIR filter dengan jendela Hanning
        numtaps = 101  # Jumlah tap filter
        cutoff = 1000  # Frekuensi cut-off (Hz)
        fir_coeff = signal.firwin(numtaps, cutoff, window='hann', fs=sr)

        # Terapkan filter FIR pada sinyal
        filtered_signal_fir = signal.lfilter(fir_coeff, 1.0, y)

        # Path file output
        output_path = os.path.join(output_folder, 'filtered_hanning_lowpass_fir.wav')
        sf.write(output_path, filtered_signal_fir, sr)

        # Plot sinyal asli dan sinyal hasil filter
        plt.figure(figsize=(15, 6))

        plt.subplot(4, 1, 1)
        plt.plot(y)
        plt.title('Sinyal Asli')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')

        plt.subplot(4, 1, 2)
        plt.plot(filtered_signal_fir)
        plt.title('Sinyal Hasil Low-pass FIR Filter dengan Jendela Hanning')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')

         # Plot respons impuls
        plt.subplot(4, 2, 5)
        plt.stem(fir_coeff)
        plt.title('Respons Impuls Filter')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')

        # Plot respons frekuensi
        plt.subplot(4, 2, 6)
        w, h = signal.freqz(fir_coeff, worN=8000)
        plt.plot(0.5 * sr * w / np.pi, np.abs(h), 'b')
        plt.title('Respons Frekuensi Filter')
        plt.xlabel('Frequency (Hz)')
        plt.ylabel('Gain')

        plt.tight_layout()
        plt.show()

        print(f"Sinyal hasil filter disimpan di: {output_path}")
# Out:
# Folder tidak ditemukan: C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window

# %%
import numpy as np
import scipy.signal as signal
import librosa
import matplotlib.pyplot as plt
import soundfile as sf
import os

# Path file audio input
file_path = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window\Indo.wav'

# Path folder untuk menyimpan hasil
output_folder = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window'

# Cek apakah folder output ada
if not os.path.exists(output_folder):
    print(f"Folder tidak ditemukan: {output_folder}")
else:
    # Cek apakah file audio ada
    if not os.path.exists(file_path):
        print(f"File tidak ditemukan: {file_path}")
    else:
        # Muat file audio
        y, sr = librosa.load(file_path, sr=None)

        # Desain band-pass FIR filter dengan jendela rectangular
        numtaps = 101  # Jumlah tap filter
        lowcut = 1000  # Frekuensi cut-off bawah (Hz)
        fir_coeff = signal.firwin(numtaps, [lowcut], pass_zero=False, window='boxcar', fs=sr)

        # Terapkan filter FIR pada sinyal
        filtered_signal_fir = signal.lfilter(fir_coeff, 1.0, y)

        # Path file output
        output_path = os.path.join(output_folder, 'filtered_boxcar_bandpass_fir.wav')
        sf.write(output_path, filtered_signal_fir, sr)

        # Plot sinyal asli dan sinyal hasil filter
        plt.figure(figsize=(15, 6))

        plt.subplot(4, 1, 1)
        plt.plot(y)
        plt.title('Sinyal Asli')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')

        plt.subplot(4, 1, 2)
        plt.plot(filtered_signal_fir)
        plt.title('Sinyal Hasil Low-pass FIR Filter dengan Jendela Rectangular')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')

         # Plot respons impuls
        plt.subplot(4, 2, 5)
        plt.stem(fir_coeff)
        plt.title('Respons Impuls Filter')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')

        # Plot respons frekuensi
        plt.subplot(4, 2, 6)
        w, h = signal.freqz(fir_coeff, worN=8000)
        plt.plot(0.5 * sr * w / np.pi, np.abs(h), 'b')
        plt.title('Respons Frekuensi Filter')
        plt.xlabel('Frequency (Hz)')
        plt.ylabel('Gain')

        plt.tight_layout()
        plt.show()

        print(f"Sinyal hasil filter disimpan di: {output_path}")
# Out:
# Folder tidak ditemukan: C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window

# %%
import numpy as np
import scipy.signal as signal
import librosa
import matplotlib.pyplot as plt
import soundfile as sf
import os

# Path file audio input
file_path = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window\Indo.wav'

# Path folder untuk menyimpan hasil
output_folder = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window'

# Cek apakah folder output ada
if not os.path.exists(output_folder):
    print(f"Folder tidak ditemukan: {output_folder}")
else:
    # Cek apakah file audio ada
    if not os.path.exists(file_path):
        print(f"File tidak ditemukan: {file_path}")
    else:
        # Muat file audio
        y, sr = librosa.load(file_path, sr=None)

        # Desain band-pass FIR filter dengan jendela rectangular
        numtaps = 101  # Jumlah tap filter
        lowcut = 1000  # Frekuensi cut-off bawah (Hz)
        fir_coeff = signal.firwin(numtaps, [lowcut], pass_zero=False, window='hamming', fs=sr)

        # Terapkan filter FIR pada sinyal
        filtered_signal_fir = signal.lfilter(fir_coeff, 1.0, y)

        # Path file output
        output_path = os.path.join(output_folder, 'filtered_hamming_bandpass_fir.wav')
        sf.write(output_path, filtered_signal_fir, sr)

        # Plot sinyal asli dan sinyal hasil filter
        plt.figure(figsize=(15, 6))

        plt.subplot(4, 1, 1)
        plt.plot(y)
        plt.title('Sinyal Asli')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')

        plt.subplot(4, 1, 2)
        plt.plot(filtered_signal_fir)
        plt.title('Sinyal Hasil Low-pass FIR Filter dengan Jendela Hamming')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')

         # Plot respons impuls
        plt.subplot(4, 2, 5)
        plt.stem(fir_coeff)
        plt.title('Respons Impuls Filter')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')

        # Plot respons frekuensi
        plt.subplot(4, 2, 6)
        w, h = signal.freqz(fir_coeff, worN=8000)
        plt.plot(0.5 * sr * w / np.pi, np.abs(h), 'b')
        plt.title('Respons Frekuensi Filter')
        plt.xlabel('Frequency (Hz)')
        plt.ylabel('Gain')

        plt.tight_layout()
        plt.show()

        print(f"Sinyal hasil filter disimpan di: {output_path}")
# Out:
# Folder tidak ditemukan: C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window

# %%
import numpy as np
import scipy.signal as signal
import librosa
import matplotlib.pyplot as plt
import soundfile as sf
import os

# Path file audio input
file_path = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window\Indo.wav'

# Path folder untuk menyimpan hasil
output_folder = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window'

# Cek apakah folder output ada
if not os.path.exists(output_folder):
    print(f"Folder tidak ditemukan: {output_folder}")
else:
    # Cek apakah file audio ada
    if not os.path.exists(file_path):
        print(f"File tidak ditemukan: {file_path}")
    else:
        # Muat file audio
        y, sr = librosa.load(file_path, sr=None)

        # Desain low-pass FIR filter dengan jendela Kaiser
        numtaps = 101  # Jumlah tap filter
        cutoff = 1000  # Frekuensi cut-off (Hz)
        beta = 14  # Beta untuk window Kaiser
        fir_coeff = signal.firwin(numtaps, cutoff, window=('kaiser', beta), fs=sr)

        # Terapkan filter FIR pada sinyal
        filtered_signal_fir = signal.lfilter(fir_coeff, 1.0, y)

        # Path file output
        output_path = os.path.join(output_folder, 'filtered_kaiser_lowpass_fir.wav')
        sf.write(output_path, filtered_signal_fir, sr)

        # Plot sinyal asli dan sinyal hasil filter
        plt.figure(figsize=(15, 6))

        plt.subplot(4, 1, 1)
        plt.plot(y)
        plt.title('Sinyal Asli')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')

        plt.subplot(4, 1, 2)
        plt.plot(filtered_signal_fir)
        plt.title('Sinyal Hasil Low-pass FIR Filter dengan Jendela Kaiser')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')

         # Plot respons impuls
        plt.subplot(4, 2, 5)
        plt.stem(fir_coeff)
        plt.title('Respons Impuls Filter')
        plt.xlabel('Sample')
        plt.ylabel('Amplitude')

        # Plot respons frekuensi
        plt.subplot(4, 2, 6)
        w, h = signal.freqz(fir_coeff, worN=8000)
        plt.plot(0.5 * sr * w / np.pi, np.abs(h), 'b')
        plt.title('Respons Frekuensi Filter')
        plt.xlabel('Frequency (Hz)')
        plt.ylabel('Gain')

        plt.tight_layout()
        plt.show()

        print(f"Sinyal hasil filter disimpan di: {output_path}")
# Out:
# Folder tidak ditemukan: C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window

# %%
import numpy as np
import scipy.signal as signal
import librosa
import matplotlib.pyplot as plt
import soundfile as sf
import os

# Path file audio input
file_path = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window\Indo.wav'

# Path folder untuk menyimpan hasil
output_folder = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window'

# Cek apakah folder output ada
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Folder dibuat: {output_folder}")

# Cek apakah file audio ada
if not os.path.exists(file_path):
    print(f"File tidak ditemukan: {file_path}")
else:
    # Muat file audio
    y, sr = librosa.load(file_path, sr=None)  # sr=None agar menggunakan sr asli dari file

    # Desain high-pass Butterworth filter
    cutoff = 1000  # Frekuensi cut-off (Hz)
    order = 4  # Orde filter Butterworth

    # Frekuensi Nyquist
    nyquist = 0.5 * sr
    
    # Rancang filter Butterworth high-pass
    b, a = signal.butter(order, cutoff/nyquist, btype='low')

    # Terapkan filter Butterworth pada sinyal
    filtered_signal_butter = signal.lfilter(b, a, y)

    # Path file output
    output_path = os.path.join(output_folder, 'filtered_low_butterworth.wav')
    sf.write(output_path, filtered_signal_butter, sr)

    # Plot sinyal asli dan sinyal hasil filter
    plt.figure(figsize=(15, 10))

    plt.subplot(3, 1, 1)
    plt.plot(y)
    plt.title('Sinyal Asli')
    plt.xlabel('Sample')
    plt.ylabel('Amplitudo')

    plt.subplot(3, 1, 2)
    plt.plot(filtered_signal_butter)
    plt.title('Sinyal Hasil Low-pass Butterworth Filter')
    plt.xlabel('Sample')
    plt.ylabel('Amplitudo')

    # Hitung dan plot respons impuls
    plt.subplot(3, 2, 5)
    impulse_response, _ = signal.impulse((b, a))
    plt.plot(impulse_response)
    plt.title('Impulse Response')
    plt.xlabel('Sample')
    plt.ylabel('Amplitudo')

    # Hitung dan plot respons frekuensi
    plt.subplot(3, 2, 6)
    w, h = signal.freqz(b, a)
    plt.plot(w, np.abs(h))
    plt.title('Frequency Response')
    plt.xlabel('Frequency [radians/sample]')
    plt.ylabel('Amplitudo')

    plt.tight_layout()
    plt.show()

    print(f"Sinyal hasil filter disimpan di: {output_path}")
# Out:
# Folder dibuat: C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window
# File tidak ditemukan: C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window\Indo.wav

# %%
import numpy as np
import scipy.signal as signal
import librosa
import matplotlib.pyplot as plt
import soundfile as sf
import os

# Path file audio input
file_path = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window\Indo.wav'

# Path folder untuk menyimpan hasil
output_folder = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window'

# Cek apakah folder output ada
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Folder dibuat: {output_folder}")

# Cek apakah file audio ada
if not os.path.exists(file_path):
    print(f"File tidak ditemukan: {file_path}")
else:
    # Muat file audio
    y, sr = librosa.load(file_path, sr=None)  # sr=None agar menggunakan sr asli dari file

    # Desain high-pass Chebyshev filter
    cutoff = 1000  # Frekuensi cut-off (Hz)
    order = 4  # Orde filter Chebyshev

    # Frekuensi Nyquist
    nyquist = 0.5 * sr
    
    # Rancang filter Chebyshev high-pass
    rp = 0.1  # Parameter ripple dalam dB, semakin kecil semakin tajam filternya
    b, a = signal.cheby1(order, rp, cutoff/nyquist, btype='low')

    # Terapkan filter Chebyshev pada sinyal
    filtered_signal_cheby = signal.lfilter(b, a, y)

    # Path file output
    output_path = os.path.join(output_folder, 'filtered_low_chebyshev.wav')
    sf.write(output_path, filtered_signal_cheby, sr)

    # Plot sinyal asli dan sinyal hasil filter
    plt.figure(figsize=(15, 10))

    plt.subplot(3, 1, 1)
    plt.plot(y)
    plt.title('Sinyal Asli')
    plt.xlabel('Sample')
    plt.ylabel('Amplitudo')

    plt.subplot(3, 1, 2)
    plt.plot(filtered_signal_cheby)
    plt.title('Sinyal Hasil Low-pass Chebyshev Filter')
    plt.xlabel('Sample')
    plt.ylabel('Amplitudo')

    # Hitung dan plot respons impuls
    plt.subplot(3, 2, 5)
    impulse_response, _ = signal.impulse((b, a))
    plt.plot(impulse_response)
    plt.title('Impulse Response')
    plt.xlabel('Sample')
    plt.ylabel('Amplitudo')

    # Hitung dan plot respons frekuensi
    plt.subplot(3, 2, 6)
    w, h = signal.freqz(b, a)
    plt.plot(w, np.abs(h))
    plt.title('Frequency Response')
    plt.xlabel('Frequency [radians/sample]')
    plt.ylabel('Amplitudo')

    plt.tight_layout()
    plt.show()

    print(f"Sinyal hasil filter disimpan di: {output_path}")
# Out:
# File tidak ditemukan: C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window\Indo.wav

# %%
import numpy as np
import scipy.signal as signal
import librosa
import matplotlib.pyplot as plt
import soundfile as sf
import os

# Path file audio input
file_path = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window\Indo.wav'

# Path folder untuk menyimpan hasil
output_folder = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window'

# Cek apakah folder output ada
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Folder dibuat: {output_folder}")

# Cek apakah file audio ada
if not os.path.exists(file_path):
    print(f"File tidak ditemukan: {file_path}")
else:
    # Muat file audio
    y, sr = librosa.load(file_path, sr=None)  # sr=None agar menggunakan sr asli dari file

    # Desain high-pass elliptic filter
    cutoff = 1000  # Frekuensi cut-off (Hz)
    order = 4  # Orde filter elliptic
    rs = 40  # Stopband attenuation (dB), semakin besar semakin tajam filternya

    # Frekuensi Nyquist
    nyquist = 0.5 * sr
    
    # Rancang filter elliptic high-pass
    b, a = signal.ellip(order, rs, rs, cutoff/nyquist, btype='low')

    # Terapkan filter elliptic pada sinyal
    filtered_signal_ellip = signal.lfilter(b, a, y)

    # Path file output
    output_path = os.path.join(output_folder, 'filtered_low_elliptic.wav')
    sf.write(output_path, filtered_signal_ellip, sr)

    # Plot sinyal asli dan sinyal hasil filter
    plt.figure(figsize=(15, 10))

    plt.subplot(3, 1, 1)
    plt.plot(y)
    plt.title('Sinyal Asli')
    plt.xlabel('Sample')
    plt.ylabel('Amplitudo')

    plt.subplot(3, 1, 2)
    plt.plot(filtered_signal_ellip)
    plt.title('Sinyal Hasil Low-pass Elliptic Filter')
    plt.xlabel('Sample')
    plt.ylabel('Amplitudo')

    # Hitung dan plot respons impuls
    plt.subplot(3, 2, 5)
    impulse_response, _ = signal.impulse((b, a))
    plt.plot(impulse_response)
    plt.title('Impulse Response')
    plt.xlabel('Sample')
    plt.ylabel('Amplitudo')

    # Hitung dan plot respons frekuensi
    plt.subplot(3, 2, 6)
    w, h = signal.freqz(b, a)
    plt.plot(w, np.abs(h))
    plt.title('Frequency Response')
    plt.xlabel('Frequency [radians/sample]')
    plt.ylabel('Amplitudo')

    plt.tight_layout()
    plt.show()

    print(f"Sinyal hasil filter disimpan di: {output_path}")
# Out:
# File tidak ditemukan: C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window\Indo.wav

# %%
import numpy as np
import scipy.signal as signal
import librosa
import matplotlib.pyplot as plt
import soundfile as sf
import os

# Path file audio input
file_path = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window\Indo.wav'

# Path folder untuk menyimpan hasil
output_folder = r'C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window'

# Cek apakah folder output ada
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
    print(f"Folder dibuat: {output_folder}")

# Cek apakah file audio ada
if not os.path.exists(file_path):
    print(f"File tidak ditemukan: {file_path}")
else:
    # Muat file audio
    y, sr = librosa.load(file_path, sr=None)  # sr=None agar menggunakan sr asli dari file

    # Desain high-pass Bessel filter
    cutoff = 1000  # Frekuensi cut-off (Hz)
    order = 4  # Orde filter Bessel

    # Frekuensi Nyquist
    nyquist = 0.5 * sr
    
    # Rancang filter Bessel high-pass
    b, a = signal.bessel(order, cutoff/nyquist, btype='low')

    # Terapkan filter Bessel pada sinyal
    filtered_signal_bessel = signal.lfilter(b, a, y)

    # Path file output
    output_path = os.path.join(output_folder, 'filtered_low_bessel.wav')
    sf.write(output_path, filtered_signal_bessel, sr)

    # Plot sinyal asli dan sinyal hasil filter
    plt.figure(figsize=(15, 10))

    plt.subplot(3, 1, 1)
    plt.plot(y)
    plt.title('Sinyal Asli')
    plt.xlabel('Sample')
    plt.ylabel('Amplitudo')

    plt.subplot(3, 1, 2)
    plt.plot(filtered_signal_bessel)
    plt.title('Sinyal Hasil Low-pass Bessel Filter')
    plt.xlabel('Sample')
    plt.ylabel('Amplitudo')

    # Hitung dan plot respons impuls
    plt.subplot(3, 2, 5)
    impulse_response, _ = signal.impulse((b, a))
    plt.plot(impulse_response)
    plt.title('Impulse Response')
    plt.xlabel('Sample')
    plt.ylabel('Amplitudo')

    # Hitung dan plot respons frekuensi
    plt.subplot(3, 2, 6)
    w, h = signal.freqz(b, a)
    plt.plot(w, np.abs(h))
    plt.title('Frequency Response')
    plt.xlabel('Frequency [radians/sample]')
    plt.ylabel('Amplitudo')

    plt.tight_layout()
    plt.show()

    print(f"Sinyal hasil filter disimpan di: {output_path}")
# Out:
# File tidak ditemukan: C:\Users\hassa\ドキュメント\Perkuliahan\PSD Window\Indo.wav
